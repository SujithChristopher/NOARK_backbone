# %%
import csv
import gpiod
import numpy as np
import cv2
from cv2 import aruco
import platform
import toml
import os
from datetime import datetime
import time
import argparse 
import sys
import keyboard
